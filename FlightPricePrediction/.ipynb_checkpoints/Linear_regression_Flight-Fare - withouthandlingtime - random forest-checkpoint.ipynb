# %% [markdown]
# # <font color="gray">Problem Statement :
# Flight ticket prices can be something hard to guess, today we might see a price, check out the price of the same flight tomorrow, it will be a different story. We might have often heard travelers saying that flight ticket prices are so unpredictable. That’s why we will try to use machine learning to solve this problem. This can help airlines by predicting what prices they can maintain.
#
# Task 1:-Prepare a complete data analysis report on the given data.
#
# Task 2:-Create a predictive model which will help the customers to predict future flight prices and plan their journey accordingly.

# %% [markdown]
# ### Import basic libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Load dataset

# %%
data=pd.read_excel("flight-fareData\Flight_Fare.xlsx")

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %% [markdown]
# ## Domain Analysis
#
# * Price is target
#
# *   "Airline" "Date_of_Journey" "Source" "Destination" "Route" "Dep_Time" "Arrival_Time" "Duration" "Total_Stops" and "Additional_Info" : are input variables
#
# * These variables collectively provide information about flights, their schedules, routes, and various details that passengers or booking systems might need when making travel arrangements or reservations.

# %% [markdown]
# ### Basic Checks

# %%
# shape
data.shape
# Out:
# (10683, 11)

# %% [markdown]
# * <b><font color="green">Size of the Dataset: </b>
#
# The dataset contains 10683 data records, which is a moderately large dataset. This can provide a substantial amount of information for analysis.

# %%
# print all columns
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
# dtypes
data.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# * The data consists of 10 categorical columns and 1 numerical column.

# %%
# head
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
# tail
data.tail()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10678              CCU → BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %%
# info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
# describe ( for numerical values)
data.describe().T
# Out:
#          count         mean          std     min     25%     50%      75%  \
# Price  10683.0  9087.064121  4611.359167  1759.0  5277.0  8372.0  12373.0
#
#            max
# Price  79512.0

# %% [markdown]
# ### Insights
#
# * <b><font color="green">Mean Price:</b>
#
# The average price of the flights in the dataset is approximately 9087. This represents the central tendency of the prices. It can serve as a reference point to understand the typical cost of flights in the dataset.
#
# * <b><font color="green">Standard Deviation: </b>
#
# The standard deviation of approximately 4611 indicates the spread or dispersion of prices around the mean. A higher standard deviation suggests that the prices in the dataset vary widely from the average. In this case, the relatively high standard deviation suggests that flight prices have a significant degree of variability.
#
# * <b><font color="green">Minimum Price: </b>
#
# The lowest recorded price in the dataset is 1759. This information indicates that there are relatively affordable flight options available in the dataset.
#
# * <b><font color="green">Maximum flight price : </b>
#
# The maximum flight price of 79512 indicates that there are some relatively expensive flight options included in the data, possibly for premium or long-distance flights or special classes.

# %%
# describe ( for catégorical values)
data.describe(include='O')
# Out:
#             Airline Date_of_Journey Source Destination            Route  \
# count         10683           10683  10683       10683            10682
# unique           12              44      5           6              128
# top     Jet Airways      18/05/2019  Delhi      Cochin  DEL → BOM → COK
# freq           3849             504   4537        4537             2376
#
#        Dep_Time Arrival_Time Duration Total_Stops Additional_Info
# count     10683        10683    10683       10682           10683
# unique      222         1343      368           5              10
# top       18:55        19:00   2h 50m      1 stop         No info
# freq        233          423      550        5625            8345

# %% [markdown]
# ### Insights
#
# * <b><font color="green">Airline Distribution:</b>
#
# <b>Jet Airways </b> is the most common airline, accounting for approximately <b>36%</b> of the dataset.
# The remaining airlines make up the remaining 64% of the dataset.
#
# * <b><font color="green">Source Distribution:</b>
#
# Flights departing from <b>Delhi</b> make up about <b>42.5%</b> of the dataset.
# The other source locations account for the remaining 57.5%.
#
# * <b><font color="green">Destination Distribution:</b>
#
# Flights heading to <b>Cochin</b> make up approximately <b>42.5%</b> of the dataset.
# The other destination locations account for the remaining 57.5%.
#
# * <b><font color="green">Route Distribution:</b>
#
# The route <b>"DEL → BOM → COK"</b> is the most common and represents about <b>22.2%</b> of the dataset.
# The other routes are less frequent.
#
# * <b><font color="green">Duration Distribution:</b>
#
# The duration <b>"2h 50m"</b> is the most common, representing approximately <b>52.6%</b> of the dataset.
# Other durations are less frequent.
#
# * <b><font color="green">Total Stops Distribution:</b>
#
# Flights with <b>"1 stop"</b> account for the majority, making up around <b>52.7%</b> of the dataset.
# Flights with other stop counts are less common.
#
# * <b><font color="green">Additional Info Distribution:</b>
#
# This column is dominated by the <b>"No info"</b> value, which accounts for approximately <b>80%</b> of the data. Consequently, it is advisable to remove or exclude this column from the dataset.
#
# * The columns related to <b>'Departure Time Distribution'</b> <b>'Date of Journey Distribution'</b> and <b>'Arrival Time Distribution'</b> appear to contain less significant information at this stage. We will reevaluate their importance and relevance after performing data preprocessing and analysis.

# %%
# Check for missing values
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
# check percentage of missing values
data.isnull().sum()/len(data)
# Out:
# Airline            0.000000
# Date_of_Journey    0.000000
# Source             0.000000
# Destination        0.000000
# Route              0.000094
# Dep_Time           0.000000
# Arrival_Time       0.000000
# Duration           0.000000
# Total_Stops        0.000094
# Additional_Info    0.000000
# Price              0.000000
# dtype: float64

# %% [markdown]
# * Only Two rows with missing values from 10683. This two rows can be considered for removal in subsequent data cleaning processes.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### univariate analysis
# * Analysing single variables
# * check the distribution of each column

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %% [markdown]
# * <b><font color="green">Check distribution of Price</b>

# %%
# Plot the distribution of prices using a histogram
plt.figure(figsize=(7, 3))
sns.histplot(data=df, x='Price', bins=20, kde=True)  
# Adjust the number of bins as needed
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Flight Prices')
plt.show()

# %%
# Plot the distribution of flights by airline
plt.figure(figsize=(9, 6))
sns.countplot(data=df, x='Airline', order=df['Airline'].value_counts().index)
plt.xticks(rotation=90)
plt.xlabel('Airline')
plt.ylabel('Number of Flights')
plt.title('Distribution of Flights by Airline')
plt.show()

# %%
# Extract hours and minutes from the 'Duration' column
df['Duration_hours'] = df['Duration'].str.extract('(\d+)h').astype(float)
df['Duration_minutes'] = df['Duration'].str.extract('(\d+)m').astype(float)

# Calculate total duration in minutes
df['Total_Duration_minutes'] = df['Duration_hours'] * 60 + df['Duration_minutes']
most_common_value = df['Total_Duration_minutes'].value_counts().idxmax()
print("Value with the maximum frequency:", most_common_value)
#Plot the distribution of flight durations using a histogram
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Total_Duration_minutes', bins=20, kde=True)  
plt.xlabel('Duration (minutes)')
plt.ylabel('Frequency')
plt.title('Distribution of Flight Durations')
plt.show()
# Out:
# Value with the maximum frequency: 170.0

# %% [markdown]
# ### Insights
#
# * <b><font color="green">The price data exhibits skewness and does not follow a normal distribution.  </b>
# * <b><font color="green">Jet Airways Business have the hignest number of flights. </b>
# * <b><font color="green">The most fréquent Duration of flights by minutes is approximatly 3 hours . </b>

# %%
## Univariate Analysis
# !pip install sweetviz
# Out:
# Requirement already satisfied: sweetviz in c:\users\user\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\user\anaconda3\lib\site-packages (from sweetviz) (3.7.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\user\anaconda3\lib\site-packages (from sweetviz) (1.10.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\user\anaconda3\lib\site-packages (from sweetviz) (1.23.5)
# Requirement already satisfied: importlib-resources>=1.2.0 in c:\users\user\anaconda3\lib\site-packages (from sweetviz) (5.12.0)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\user\anaconda3\lib\site-packages (from sweetviz) (4.64.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\user\anaconda3\lib\site-packages (from sweetviz) (1.5.3)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\user\anaconda3\lib\site-packages (from sweetviz) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (22.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2022.7)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)

# %%
import sweetviz as sv#importing sweetviz library 
my_report1 = sv.analyze(data)#syntax to use sweetviz
my_report1.show_html()#Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
my_report1.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# !function(e,t){&quot;use strict&quot;;&quot;object&quot;==typeof module&amp;&amp;&quot;object&quot;==typeof module.exports?module.exports=e.document?t(e,!0):function(e){if(!e.document)throw new Error(&quot;jQuery requires a window with a document&quot;);return t(e)}:t(e)}(&quot;undefined&quot;!=typeof window?window:this,function(C,e){&quot;use strict&quot;;var t=[],E=C.document,r=Object.getPrototypeOf,s=t.slice,g=t.concat,u=t.push,i=t.indexOf,n={},o=n.toString,v=n.hasOwnProperty,a=v.toString,l=a.call(Object),y={},m=function(e){return&quot;function&quot;==typeof e&amp;&amp;&quot;number&quot;!=typeof e.nodeType},x=function(e){return null!=e&amp;&amp;e===e.window},c={type:!0,src:!0,nonce:!0,noModule:!0};function b(e,t,n){var r,i,o=(n=n||E).createElement(&quot;script&quot;);if(o.text=e,t)for(r in c)(i=t[r]||t.getAttribute&amp;&amp;t.getAttribute(r))&amp;&amp;o.setAttribute(r,i);n.head.appendChild(o).parentNode.removeChild(o)}function w(e){return null==e?e+&quot;&quot;:&quot;object&quot;==typeof e||&quot;function&quot;==typeof e?n[o.call(e)]||&quot;object&quot;:typeof e}var f=&quot;3.4.1&quot;,k=function(e,t){return new k.fn.init(e,t)},p=/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g;function d(e){var t=!!e&amp;&amp;&quot;length&quot;in e&amp;&amp;e.length,n=w(e);return!m(e)&amp;&amp;!x(e)&amp;&amp;(&quot;array&quot;===n||0===t||&quot;number&quot;==typeof t&amp;&amp;0&lt;t&amp;&amp;t-1 in e)}k.fn=k.prototype={jquery:f,constructor:k,length:0,toArray:function(){return s.call(this)},get:function(e){return null==e?s.call(this):e&lt;0?this[e+this.length]:this[e]},pushStack:function(e){var t=k.merge(this.constructor(),e);return t.prevObject=this,t},each:function(e){return k.each(this,e)},map:function(n){return this.pushStack(k.map(this,function(e,t){return n.call(e,t,e)}))},slice:function(){return this.pushStack(s.apply(this,arguments))},first:function(){return this.eq(0)},last:function(){return this.eq(-1)},eq:function(e){var t=this.length,n=+e+(e&lt;0?t:0);return this.pushStack(0&lt;=n&amp;&amp;n&lt;t?[this[n]]:[])},end:function(){return this.prevObject||this.constructor()},push:u,sort:t.sort,splice:t.splice},k.extend=k.fn.extend=function(){var e,t,n,r,i,o,a=arguments[0]||{},s=1,u=arguments.length,l=!1;for(&quot;boolean&quot;==typeof a&amp;&amp;(l=a,a=arguments[s]||{},s++),&quot;object&quot;==typeof a||m(a)||(a={}),s===u&amp;&amp;(a=this,s--);s&lt;u;s++)if(null!=(e=arguments[s]))for(t in e)r=e[t],&quot;__proto__&quot;!==t&amp;&amp;a!==r&amp;&amp;(l&amp;&amp;r&amp;&amp;(k.isPlainObject(r)||(i=Array.isArray(r)))?(n=a[t],o=i&amp;&amp;!Array.isArray(n)?[]:i||k.isPlainObject(n)?n:{},i=!1,a[t]=k.extend(l,o,r)):void 0!==r&amp;&amp;(a[t]=r));return a},k.extend({expando:&quot;jQuery&quot;+(f+Math.random()).replace(/\D/g,&quot;&quot;),isReady:!0,error:function(e){throw new Error(e)},noop:function(){},isPlainObject:function(e){var t,n;return!(!e||&quot;[object Object]&quot;!==o.call(e))&amp;&amp;(!(t=r(e))||&quot;function&quot;==typeof(n=v.call(t,&quot;constructor&quot;)&amp;&amp;t.constructor)&amp;&amp;a.call(n)===l)},isEmptyObject:function(e){var t;for(t in e)return!1;return!0},globalEval:function(e,t){b(e,{nonce:t&amp;&amp;t.nonce})},each:function(e,t){var n,r=0;if(d(e)){for(n=e.length;r&lt;n;r++)if(!1===t.call(e[r],r,e[r]))break}else for(r in e)if(!1===t.call(e[r],r,e[r]))break;return e},trim:function(e){return null==e?&quot;&quot;:(e+&quot;&quot;).replace(p,&quot;&quot;)},makeArray:function(e,t){var n=t||[];return null!=e&amp;&amp;(d(Object(e))?k.merge(n,&quot;string&quot;==typeof e?[e]:e):u.call(n,e)),n},inArray:function(e,t,n){return null==t?-1:i.call(t,e,n)},merge:function(e,t){for(var n=+t.length,r=0,i=e.length;r&lt;n;r++)e[i++]=t[r];return e.length=i,e},grep:function(e,t,n){for(var r=[],i=0,o=e.length,a=!n;i&lt;o;i++)!t(e[i],i)!==a&amp;&amp;r.push(e[i]);return r},map:function(e,t,n){var r,i,o=0,a=[];if(d(e))for(r=e.length;o&lt;r;o++)null!=(i=t(e[o],o,n))&amp;&amp;a.push(i);else for(o in e)null!=(i=t(e[o],o,n))&amp;&amp;a.push(i);return g.apply([] ...

# %% [markdown]
# ## Data Exploration :
#
# ### Bivariate analysis

# %%
# Plot the distribution of Price by Airline
plt.figure(figsize=(9, 6))
sns.barplot(x='Airline', y='Price', data=df)
plt.title('Average Price by Airline')
plt.xticks(rotation=90)
plt.xlabel('Airline')
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
# ### Insights
#
# * <b><font color="green">Jet Airways Business have the hignest average of price and the hignest number of flights </b>

# %%
# Plot the distribution of price durations using a histogram
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Price', bins=20, kde=True)  
plt.xlabel('Duration (minutes)')
plt.ylabel('Price')
plt.title('Distribution of Flight by Durations')
plt.show()

# %% [markdown]
# ### Insights
#
# * <b><font color="green">The price and duration have an inverse relationship, where a shorter duration corresponds to a higher price. </b>

# %%
#  Date Analysis
# Convert 'Date_of_Journey' to datetime
df['Date_of_Journey'] = pd.to_datetime(df['Date_of_Journey'])
# Extract month from 'Date_of_Journey'
df['Journey_Month'] = df['Date_of_Journey'].dt.month
# Box plot of Price by Month
plt.figure(figsize=(7, 4))
sns.boxplot(x='Journey_Month', y='Price', data=df)
plt.title('Price Variation by Month of Journey')
plt.xlabel('Month')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ### Insights
#
# * <b><font color="green">There is no price variation based on the month.There is some minor variability, but it's not significant. </b>

# %%
# Correlation Analysis
corr_matrix = df.corr()
print(corr_matrix['Price'])
# Out:
# Price                     1.000000
# Duration_hours            0.508985
# Duration_minutes         -0.115713
# Total_Duration_minutes    0.512132
# Journey_Month             0.010700
# Name: Price, dtype: float64

# %% [markdown]
# # Insights
#
# * the price tends to increase as the duration (in both hours and total minutes) increases, suggesting a positive relationship. However, the month of the journey has almost no influence on the price.
# * Additionally, the correlation with 'Duration_minutes' is very weak, indicating that it has minimal impact on the price.

# %%
print(data.columns)
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price', 'Duration_hours', 'Duration_minutes',
#        'Total_Duration_minutes', 'Journey_Month'],
#       dtype='object')

# %%
data.drop("Duration_hours", axis = 1, inplace = True)

# %%
data.drop("Duration_minutes", axis = 1, inplace = True)

# %%
data.drop("Total_Duration_minutes", axis = 1, inplace = True)

# %%
data.drop("Journey_Month", axis = 1, inplace = True)

# %%
print(data.columns)
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %% [markdown]
# # Data Preprocessing

# %%
# number of rows with missing values is relatively small compared to your dataset's size
#and removing them doesn't significantly impact the quality of your data==> i will drop these rows.

# %%
data.dropna(subset=['Route'], inplace=True)

# %%
data.dropna(subset=['Total_Stops'], inplace=True)

# %%
# Re check for missing values
data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# ## Check for duplicates and handling them

# %%
# check for duplicate values
data.duplicated().sum()
# Out:
# 220

# %%
#Remove Duplicate Rows
data.drop_duplicates(inplace=True)

# %%
# Re check for duplicate values
data.duplicated().sum()
# Out:
# 0

# %%
data.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time                   object
# Arrival_Time               object
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# dtype: object

# %% [markdown]
# ## Check for outliers

# %%
# check outliers in price
sns.boxplot(x=data.Price)
# Out:
# <Axes: xlabel='Price'>

# %% [markdown]
# * <I> We can see many outliers in Price column.</I>
# * <I> outliers in Price are seen toward right side.</I>

# %% [markdown]
# * To handle those outliers
# * IQR- Use this method when data is not normal
# * 3-sigma rule - use this method when data is normal

# %% [markdown]
# <b><font color="green">Steps:</font></b>
# * find Q1 and Q3
# * fid IQR=Q3-Q1
# * find lower limit and upper limit
# * lower_limit=Q1-1.5*IQR
# * upper_limit=Q3+1.5*IQR
# * Find records/values which are greater than upper limit and less than lower limit

# %%
# find Q1 and Q3
Q1=data['Price'].quantile(0.25)
print("lower quartile",Q1)
Q3=data['Price'].quantile(0.75)
print("upper quartile",Q3)
# Out:
# lower quartile 5224.0
# upper quartile 12344.75

# %%
# find IQR
IQR=Q3-Q1
IQR
# Out:
# 7120.75

# %%
# find lower limit and upper limit
lower_limit=Q1-1.5*IQR
print("lower limit is",lower_limit)
upper_limit=Q3+1.5*IQR
print("upper_limit is",upper_limit)
# Out:
# lower limit is -5457.125
# upper_limit is 23025.875

# %%
# find values above upper_limit
data.loc[data['Price']>upper_limit]
# Out:
#                     Airline Date_of_Journey    Source Destination  \
# 123               Air India      2019-01-03     Delhi      Cochin
# 396       Multiple carriers      2019-01-03     Delhi      Cochin
# 486             Jet Airways      2019-01-03  Banglore   New Delhi
# 510             Jet Airways      2019-01-03  Banglore   New Delhi
# 597               Air India      2019-06-03    Mumbai   Hyderabad
# ...                     ...             ...       ...         ...
# 10353           Jet Airways      2019-06-03    Mumbai   Hyderabad
# 10364  Jet Airways Business      2019-01-03  Banglore   New Delhi
# 10383           Jet Airways      2019-01-03  Banglore   New Delhi
# 10439           Jet Airways      2019-01-03  Banglore   New Delhi
# 10511             Air India      2019-01-03  Banglore   New Delhi
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 123          DEL → BOM → COK    23:00  19:15 02 Mar  20h 15m      1 stop
# 396          DEL → BOM → COK    12:50         19:15   6h 25m      1 stop
# 486          BLR → BOM → DEL    08:55         15:15   6h 20m      1 stop
# 510          BLR → BOM → DEL    07:00         12:25   5h 25m      1 stop
# 597    BOM → JDH → DEL → HYD    09:40  15:15 07 Mar  29h 35m     2 stops
# ...                      ...      ...           ...      ...         ...
# 10353  BOM → BDQ → DEL → HYD    19:50  16:50 07 Mar      21h     2 stops
# 10364        BLR → MAA → DEL    09:45         14:25   4h 40m      1 stop
# 10383        BLR → BOM → DEL    07:00  05:05 02 Mar   22h 5m      1 stop
# 10439        BLR → BOM → DEL    18:40  09:00 02 Mar  14h 20m      1 stop
# 10511  BLR → BOM → BHO → DEL    06:45  09:25 02 Mar  26h 40m     2 stops
#
#       Additional_Info  Price
# 123           No info  27430
# 396           No info  36983
# 486           No info  26890
# 510           No info  26890
# 597           No info  25139
# ...               ...    ...
# 10353         No info  24210
# 10364  Business class  57209
# 10383         No info  26890
# 10439         No info  31825
# 10511  2 Long layover  26480
#
# [94 rows x 11 columns]

# %%
len(data.loc[data['Price']>upper_limit])/len(data)
# Out:
# 0.008984897725100364

# %%
# find values below lower limit
data.loc[data['Price']<lower_limit]
# Out:
# Empty DataFrame
# Columns: [Airline, Date_of_Journey, Source, Destination, Route, Dep_Time, Arrival_Time, Duration, Total_Stops, Additional_Info, Price]
# Index: []

# %%
# How to handle outliers
# since data is not normal will replace outliers with median
data.loc[data['Price']>upper_limit,"Price"]=data["Price"].median()

# %%
# check are there any outliers in Price
sns.boxplot(x=data.Price)
# Out:
# <Axes: xlabel='Price'>

# %% [markdown]
# # Data Processing

# %%
print(data.columns)
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder


# Encode categorical variables

    # As Airline is Nominal Categorical data we will perform OneHotEncoding

Airline = data[["Airline"]]

Airline = pd.get_dummies(Airline, drop_first= True)

Airline.head()

# As Source is Nominal Categorical data we will perform OneHotEncoding

Source = data[["Source"]]

Source = pd.get_dummies(Source, drop_first = True)

Source.head()



# As Destination is Nominal Categorical data we will perform OneHotEncoding

Destination = data[["Destination"]]

Destination = pd.get_dummies(Destination, drop_first = True)

Destination.head()

data = pd.concat([data, Airline, Source, Destination], axis = 1)



# Replace Values 'Total_Stops' with corresponding keys

data.replace({"non-stop": 0, "1 stop": 1, "2 stops": 2, "3 stops": 3, "4 stops": 4}, inplace = True)

    
# 'Duration'
# Convert Duration to total minutes
data['Duration_hours'] = data['Duration'].str.extract(r'(\d+)h').astype(float).fillna(0)
data['Duration_minutes'] = data['Duration'].str.extract(r'(\d+)m').astype(float).fillna(0)

# keep only total
#data['Duration_total_minutes'] = data['Duration_hours'] * 60 + data['Duration_minutes']

# 'Date_of_Journey'
# Parse Date_of_Journey column and extract features (day, month, year)
data['Date_of_Journey'] = pd.to_datetime(data['Date_of_Journey'], format='%d/%m/%Y')
data['Journey_day'] = data['Date_of_Journey'].dt.day
data['Journey_month'] = data['Date_of_Journey'].dt.month
data['Journey_year'] = data['Date_of_Journey'].dt.year

# 'Dep_Time'
# Extract hours and minutes from Dep_Time
data['Dep_Hours'] = data['Dep_Time'].str.extract(r'(\d+):(\d+)')[0].astype(int)
data['Dep_Minutes'] = data['Dep_Time'].str.extract(r'(\d+):(\d+)')[1].astype(int)

# Convert Dep_Time to minutes
#data['Dep_Minutes_Since_Midnight'] = data['Dep_Hours'] * 60 + data['Dep_Minutes']


# 'Arrival_Time'
# Extract time of arrival (if available)
data['Arrival_Time'] = data['Arrival_Time'].str.extract(r'(\d+:\d+)')
# Extract day and month (if available)
data['Arrival_Day'] = data['Arrival_Time'].str.extract(r'(\d+) (\w{3})')[0]
data['Arrival_Month'] = data['Arrival_Time'].str.extract(r'(\d+) (\w{3})')[1]

# Convert the extracted values to datetime
data['Arrival_Time'] = pd.to_datetime(data['Arrival_Time'], format='%H:%M').dt.hour * 60 + pd.to_datetime(data['Arrival_Time'], format='%H:%M').dt.minute

# %%
data.isnull().sum()
# Out:
# Airline                                          0
# Date_of_Journey                                  0
# Source                                           0
# Destination                                      0
# Route                                            0
# Dep_Time                                         0
# Arrival_Time                                     0
# Duration                                         0
# Total_Stops                                      0
# Additional_Info                                  0
# Price                                            0
# Airline_Air India                                0
# Airline_GoAir                                    0
# Airline_IndiGo                                   0
# Airline_Jet Airways                              0
# Airline_Jet Airways Business                     0
# Airline_Multiple carriers                        0
# Airline_Multiple carriers Premium economy        0
# Airline_SpiceJet                                 0
# Airline_Trujet                                   0
# Airline_Vistara                                  0
# Airline_Vistara Premium economy                  0
# Source_Chennai                                   0
# Source_Delhi                                     0
# Source_Kolkata                                   0
# Source_Mumbai                                    0
# Destination_Cochin                               0
# Destination_Delhi                                0
# Destination_Hyderabad                            0
# Destination_Kolkata                              0
# Destination_New Delhi                            0
# Duration_hours                                   0
# Duration_minutes                                 0
# Journey_day                                      0
# Journey_month                                    0
# Journey_year                                     0
# Dep_Hours                                        0
# Dep_Minutes                                      0
# Arrival_Day                                  10462
# Arrival_Month                                10462
# dtype: int64

# %%
# keep Dep_Minutes_Since_Midnight
data.drop(columns=['Dep_Time'], inplace=True)

# %%
# keep only month
data.drop(columns=['Date_of_Journey'], inplace=True)

# %%
# all data is in 2019
# Consequently, this column will be removed from the dataset.
data.drop(columns=['Journey_year'], inplace=True)

# %%
# Additional_Info column is dominated by the "No info" value, which accounts for approximately 80% of the data. 
# Consequently, this column will be removed from the dataset.
data.drop(columns=['Additional_Info'], inplace=True)

# %%
# we will drop root because we find info in number stops
data.drop(columns=['Route'], inplace=True)

# %%
# we will keep only Duration_total_minutes
data.drop(columns=['Duration'], inplace=True)

# %%
# we will keep only Duration_total_minutes
data.drop(columns=['Arrival_Day', 'Arrival_Month'], inplace=True)

# %%
print(data.columns)
# Out:
# Index(['Airline', 'Source', 'Destination', 'Arrival_Time', 'Total_Stops',
#        'Price', 'Airline_Air India', 'Airline_GoAir', 'Airline_IndiGo',
#        'Airline_Jet Airways', 'Airline_Jet Airways Business',
#        'Airline_Multiple carriers',
#        'Airline_Multiple carriers Premium economy', 'Airline_SpiceJet',
#        'Airline_Trujet', 'Airline_Vistara', 'Airline_Vistara Premium economy',
#        'Source_Chennai', 'Source_Delhi', 'Source_Kolkata', 'Source_Mumbai',
#        'Destination_Cochin', 'Destination_Delhi', 'Destination_Hyderabad',
#        'Destination_Kolkata', 'Destination_New Delhi', 'Duration_hours',
#        'Duration_minutes', 'Journey_day', 'Journey_month', 'Dep_Hours',
#        'Dep_Minutes'],
#       dtype='object')

# %%
data.drop(columns=['Airline', 'Source', 'Destination'], inplace=True)

# %%
print(data.columns)
# Out:
# Index(['Arrival_Time', 'Total_Stops', 'Price', 'Airline_Air India',
#        'Airline_GoAir', 'Airline_IndiGo', 'Airline_Jet Airways',
#        'Airline_Jet Airways Business', 'Airline_Multiple carriers',
#        'Airline_Multiple carriers Premium economy', 'Airline_SpiceJet',
#        'Airline_Trujet', 'Airline_Vistara', 'Airline_Vistara Premium economy',
#        'Source_Chennai', 'Source_Delhi', 'Source_Kolkata', 'Source_Mumbai',
#        'Destination_Cochin', 'Destination_Delhi', 'Destination_Hyderabad',
#        'Destination_Kolkata', 'Destination_New Delhi', 'Duration_hours',
#        'Duration_minutes', 'Journey_day', 'Journey_month', 'Dep_Hours',
#        'Dep_Minutes'],
#       dtype='object')

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### <font color="green">Droping irrelevant columns and Selecting best features
#
# * Drop the columns which has very less correlation with target variables.
# * Drop one of the column if two input variables has high correlation

# %%
data.corr()
# Out:
#                                            Arrival_Time  Total_Stops  \
# Arrival_Time                                   1.000000     0.047414
# Total_Stops                                    0.047414     1.000000
# Price                                          0.042312     0.662478
# Airline_Air India                              0.086463     0.272543
# Airline_GoAir                                  0.021997    -0.057547
# Airline_IndiGo                                -0.074634    -0.294993
# Airline_Jet Airways                           -0.018169     0.197439
# Airline_Jet Airways Business                  -0.014617     0.019256
# Airline_Multiple carriers                      0.060247     0.134335
# Airline_Multiple carriers Premium economy      0.013438     0.010555
# Airline_SpiceJet                              -0.093652    -0.273128
# Airline_Trujet                                 0.003633     0.002926
# Airline_Vistara                                0.071625    -0.116775
# Airline_Vistara Premium economy                0.000705    -0.020571
# Source_Chennai                                -0.017399    -0.236125
# Source_Delhi                                  -0.009776     0.474480
# Source_Kolkata                                 0.059714     0.050105
# Source_Mumbai                                 -0.032302    -0.260668
# Destination_Cochin                            -0.009776     0.474480
# Destination_Delhi                             -0.029650    -0.450456
# Destination_Hyderabad                         -0.032302    -0.260668
# Destination_Kolkata                           -0.017399    -0.236125
# Destination_New Delhi                         -0.002888    -0.000170
# Duration_hours                                 0.062862     0.730156
# Duration_minutes                              -0.110987    -0.150253
# Journey_day                                   -0.001934    -0.035371
# Journey_month                                 -0.004014     0.065438
# Dep_Hours                                     -0.000891    -0.067523
# Dep_Minutes                                    0.045949    -0.002695
#
#                                               Price  Airline_Air India  \
# Arrival_Time                               0.042312           0.086463
# Total_Stops                                0.662478           0.272543
# Price                                      1.000000           0.061319
# Airline_Air India                          0.061319           1.000000
# Airline_GoAir                             -0.100659          -0.060418
# Airline_IndiGo                            -0.384163          -0.216526
# Airline_Jet Airways                        0.442693          -0.325139
# Airline_Jet Airways Business              -0.003322          -0.010529
# Airline_Multiple carriers                  0.168715          -0.157916
# Airline_Multiple carriers Premium economy  0.022561          -0.015504
# Airline_SpiceJet                          -0.323604          -0.127758
# Airline_Trujet                            -0.011314          -0.004298
# Airline_Vistara                           -0.055436          -0.096176
# Airline_Vistara Premium economy            0.000563          -0.007444
# Source_Chennai                            -0.193770          -0.050823
# Source_Delhi                               0.322559          -0.000284
# Source_Kolkata                             0.046496           0.022071
# Source_Mumbai                             -0.256019           0.024080
# Destination_Cochin                         0.322559          -0.000284
# Destination_Delhi                         -0.337245          -0.067512
# Destination_Hyderabad                     -0.256019           0.024080
# Destination_Kolkata                       -0.193770          -0.050823
# Destination_New Delhi                      0.107732           0.056059
# Duration_hours                             0.567567           0.260713
# Duration_minutes                          -0.147018          -0.026412
# Journey_day                               -0.147984          -0.037436
# Journey_month                              0.068811           0.002112
# Dep_Hours                                  0.004967          -0.020731
# Dep_Minutes                               -0.053522          -0.043883
#
#                                            Airline_GoAir  Airline_IndiGo  \
# Arrival_Time                                    0.021997       -0.074634
# Total_Stops                                    -0.057547       -0.294993
# Price                                          -0.100659       -0.384163
# Airline_Air India                              -0.060418       -0.216526
# Airline_GoAir                                   1.000000       -0.067711
# Airline_IndiGo                                 -0.067711        1.000000
# Airline_Jet Airways                            -0.101677       -0.364391
# Airline_Jet Airways Business                   -0.003293       -0.011800
# Airline_Multiple carriers                      -0.049383       -0.176980
# Airline_Multiple carriers Premium economy      -0.004848       -0.017376
# Airline_SpiceJet                               -0.039952       -0.143181
# Airline_Trujet                                 -0.001344       -0.004816
# Airline_Vistara                                -0.030076       -0.107787
# Airline_Vistara Premium economy                -0.002328       -0.008343
# Source_Chennai                                 -0.026722        0.141073
# Source_Delhi                                   -0.006572       -0.070208
# Source_Kolkata                                 -0.044566       -0.061402
# Source_Mumbai                                  -0.036723        0.057911
# Destination_Cochin                             -0.006572       -0.070208
# Destination_Delhi                               0.098974        0.087989
# Destination_Hyderabad                          -0.036723        0.057911
# Destination_Kolkata                            -0.026722        0.141073
# Destination_New Delhi                           0.017694       -0.026885
# Duration_hours                                 -0.092784       -0.341076
# Duration_minutes                                0.069148        0.122809
# Journey_day                                     0.003205        0.016175
# Journey_month                                  -0.017674       -0.036564
# Dep_Hours                                      -0.016309       -0.022254
# Dep_Minutes                                     0.077403       -0.014346
#
#                                            Airline_Jet Airways  \
# Arrival_Time                                         -0.018169
# Total_Stops                                           0.197439
# Price                                                 0.442693
# Airline_Air India                                    -0.325139
# Airline_GoAir                                        -0.101677
# Airline_IndiGo                                       -0.364391
# Airline_Jet Airways                                   1.000000
# Airline_Jet Airways Business                         -0.017720
# Airline_Multiple carriers                            -0.265756
# Airline_Multiple carriers Premium economy            -0.026091
# Airline_SpiceJet                                     -0.215004
# Airline_Trujet                                       -0.007232
# Airline_Vistara                                      -0.161855
# Airline_Vistara Premium economy                      -0.012528
# Source_Chennai                                       -0.143805
# Source_Delhi                                         -0.040026
# Source_Kolkata                                        0.109689
# Source_Mumbai                                        -0.022049
# Destination_Cochin                                   -0.040026
# Destination_Delhi                                    -0.047451
# Destination_Hyderabad                                -0.022049
# Destination_Kolkata                                  -0.143805
# Destination_New Delhi                                 0.066380
# Duration_hours                                        0.299088
# Duration_minutes                                     -0.096568
# Journey_day                                          -0.035165
# Journey_month                                         0.055666
# Dep_Hours                                             0.120596
# Dep_Minutes                                           0.022596
#
#                                            Airline_Jet Airways Business  \
# Arrival_Time                                                  -0.014617
# Total_Stops                                                    0.019256
# Price                                                         -0.003322
# Airline_Air India                                             -0.010529
# Airline_GoAir                                                 -0.003293
# Airline_IndiGo                                                -0.011800
# Airline_Jet Airways                                           -0.017720
# Airline_Jet Airways Business                                   1.000000
# Airline_Multiple carriers                                     -0.008606
# Airline_Multiple carriers Premium economy                     -0.000845
# Airline_SpiceJet                                              -0.006963
# Airline_Trujet                                                -0.000234
# Airline_Vistara                                               -0.005241
# Airline_Vistara Premium economy                               -0.000406
# Source_Chennai                                                -0.004657
# Source_Delhi                                                  -0.003985
# Source_Kolkata                                                -0.014693
# Source_Mumbai                                                 -0.006400
# Destination_Cochin                                            -0.003985
# Destination_Delhi                                             -0.008884
# Destination_Hyderabad                                         -0.006400
# Destination_Kolkata                                           -0.004657
# Destination_New Delhi                                          0.049146
# Duration_hours                                                -0.011512
# Duration_minutes                                              -0.002191
# Journey_day                                                   -0.026241
# Journey_month                                                 -0.026936
# Dep_Hours                                                     -0.007579
# Dep_Minutes                                                    0.009245
#
#                                            Airline_Multiple carriers  \
# Arrival_Time                                                0.060247
# Total_Stops                                                 0.134335
# Price                                                       0.168715
# Airline_Air India                                          -0.157916
# Airline_GoAir                                              -0.049383
# Airline_IndiGo                                             -0.176980
# Airline_Jet Airways                                        -0.265756
# Airline_Jet Airways Business                               -0.008606
# Airline_Multiple carriers                                   1.000000
# Airline_Multiple carriers Premium economy                  -0.012672
# Airline_SpiceJet                                           -0.104424
# Airline_Trujet                                             -0.003513
# Airline_Vistara                                            -0.078611
# Airline_Vistara Premium economy                            -0.006085
# Source_Chennai                                             -0.069844
# Source_Delhi                                                0.426279
# Source_Kolkata                                             -0.220363
# Source_Mumbai                                              -0.095984
# Destination_Cochin                                          0.426279
# Destination_Delhi                                          -0.133242
# Destination_Hyderabad                                      -0.095984
# Destination_Kolkata                                        -0.069844
# Destination_New Delhi                                      -0.111157
# Duration_hours                                              0.001100
# Duration_minutes                                           -0.118164
# Journey_day                                                 0.051439
# Journey_month                                              -0.002746
# Dep_Hours                                                  -0.151549
# Dep_Minutes                                                -0.110297
#
#                                            Airline_Multiple carriers Premium economy  \
# Arrival_Time                                                                0.013438
# Total_Stops                                                                 0.010555
# Price                                                                       0.022561
# Airline_Air India                                                          -0.015504
# Airline_GoAir                                                              -0.004848
# Airline_IndiGo                                                             -0.017376
# Airline_Jet Airways                                                        -0.026091
# Airline_Jet Airways Business                                               -0.000845
# Airline_Multiple carriers                                                  -0.012672
# Airline_Multiple carriers Premium economy                                   1.000000
# Airline_SpiceJet                                                           -0.010252
# Airline_Trujet                                                             -0.000345
# Airline_Vistara                                                            -0.007718
# Airline_Vistara Premium economy                                            -0.000597
# Source_Chennai                                                             -0.006857
# Source_Delhi                                                                0.041851
# Source_Kolkata                                                             -0.021635
# Source_Mumbai                                                              -0.009424
# Destination_Cochin                                                          0.041851
# Destination_Delhi                                                          -0.013081
# Destination_Hyderabad                                                      -0.009424
# Destination_Kolkata                                                        -0.006857
# Destination_New Delhi                                                      -0.010913
# Duration_hours                                                             -0.001406
# Duration_minutes                                                           -0.006709
# Journey_day                                                                 0.033582
# Journey_month                                                              -0.029848
# Dep_Hours                                                                  -0.029004
# Dep_Minutes                                                                -0.004653
#
#                                            ...  Destination_Delhi  \
# Arrival_Time                               ...          -0.029650
# Total_Stops                                ...          -0.450456
# Price                                      ...          -0.337245
# Airline_Air India                          ...          -0.067512
# Airline_GoAir                              ...           0.098974
# Airline_IndiGo                             ...           0.087989
# Airline_Jet Airways                        ...          -0.047451
# Airline_Jet Airways Business               ...          -0.008884
# Airline_Multiple carriers                  ...          -0.133242
# Airline_Multiple carriers Premium economy  ...          -0.013081
# Airline_SpiceJet                           ...           0.042066
# Airline_Trujet                             ...          -0.003626
# Airline_Vistara                            ...           0.102780
# Airline_Vistara Premium economy            ...           0.011035
# Source_Chennai                             ...          -0.072100
# Source_Delhi                               ...          -0.312570
# Source_Kolkata                             ...          -0.227479
# Source_Mumbai                              ...          -0.099084
# Destination_Cochin                         ...          -0.312570
# Destination_Delhi                          ...           1.000000
# Destination_Hyderabad                      ...          -0.099084
# Destination_Kolkata                        ...          -0.072100
# Destination_New Delhi                      ...          -0.114746
# Duration_hours                             ...          -0.345514
# Duration_minutes                           ...           0.224232
# Journey_day                                ...           0.013871
# Journey_month                              ...           0.008979
# Dep_Hours                                  ...           0.010428
# Dep_Minutes                                ...           0.003314
#
#                                            Destination_Hyderabad  \
# Arrival_Time                                           -0.032302
# Total_Stops                                            -0.260668
# Price                                                  -0.256019
# Airline_Air India                                       0.024080
# Airline_GoAir                                          -0.036723
# Airline_IndiGo                                          0.057911
# Airline_Jet Airways                                    -0.022049
# Airline_Jet Airways Business                           -0.006400
# Airline_Multiple carriers                              -0.095984
# Airline_Multiple carriers Premium economy              -0.009424
# Airline_SpiceJet                                        0.096827
# Airline_Trujet                                          0.036596
# Airline_Vistara                                        -0.016237
# Airline_Vistara Premium economy                        -0.004525
# Source_Chennai                                         -0.051939
# Source_Delhi                                           -0.225168
# Source_Kolkata                                         -0.163870
# Source_Mumbai                                           1.000000
# Destination_Cochin                                     -0.225168
# Destination_Delhi                                      -0.099084
# Destination_Hyderabad                                   1.000000
# Destination_Kolkata                                    -0.051939
# Destination_New Delhi                                  -0.082660
# Duration_hours                                         -0.232258
# Duration_minutes                                       -0.017203
# Journey_day                                            -0.011954
# Journey_month                                          -0.015820
# Dep_Hours                                              -0.016968
# Dep_Minutes                                             0.038091
#
#                                            Destination_Kolkata  \
# Arrival_Time                                         -0.017399
# Total_Stops                                          -0.236125
# Price                                                -0.193770
# Airline_Air India                                    -0.050823
# Airline_GoAir                                        -0.026722
# Airline_IndiGo                                        0.141073
# Airline_Jet Airways                                  -0.143805
# Airline_Jet Airways Business                         -0.004657
# Airline_Multiple carriers                            -0.069844
# Airline_Multiple carriers Premium economy            -0.006857
# Airline_SpiceJet                                      0.187183
# Airline_Trujet                                       -0.001901
# Airline_Vistara                                       0.062538
# Airline_Vistara Premium economy                       0.026844
# Source_Chennai                                        1.000000
# Source_Delhi                                         -0.163846
# Source_Kolkata                                       -0.119242
# Source_Mumbai                                        -0.051939
# Destination_Cochin                                   -0.163846
# Destination_Delhi                                    -0.072100
# Destination_Hyderabad                                -0.051939
# Destination_Kolkata                                   1.000000
# Destination_New Delhi                                -0.060149
# Duration_hours                                       -0.186251
# Duration_minutes                                     -0.098949
# Journey_day                                           0.013520
# Journey_month                                        -0.015108
# Dep_Hours                                            -0.014639
# Dep_Minutes                                           0.067710
#
#                                            Destination_New Delhi  \
# Arrival_Time                                           -0.002888
# Total_Stops                                            -0.000170
# Price                                                   0.107732
# Airline_Air India                                       0.056059
# Airline_GoAir                                           0.017694
# Airline_IndiGo                                         -0.026885
# Airline_Jet Airways                                     0.066380
# Airline_Jet Airways Business                            0.049146
# Airline_Multiple carriers                              -0.111157
# Airline_Multiple carriers Premium economy              -0.010913
# Airline_SpiceJet                                       -0.038145
# Airline_Trujet                                         -0.003025
# Airline_Vistara                                         0.018222
# Airline_Vistara Premium economy                         0.014753
# Source_Chennai                                         -0.060149
# Source_Delhi                                           -0.260761
# Source_Kolkata                                         -0.189774
# Source_Mumbai                                          -0.082660
# Destination_Cochin                                     -0.260761
# Destination_Delhi                                      -0.114746
# Destination_Hyderabad                                  -0.082660
# Destination_Kolkata                                    -0.060149
# Destination_New Delhi                                   1.000000
# Duration_hours                                          0.015801
# Duration_minutes                                        0.078637
# Journey_day                                            -0.099225
# Journey_month                                          -0.099300
# Dep_Hours                                              -0.022008
# Dep_Minutes                                             0.107839
#
#                                            Duration_hours  Duration_minutes  \
# Arrival_Time                                     0.062862         -0.110987
# Total_Stops                                      0.730156         -0.150253
# Price                                            0.567567         -0.147018
# Airline_Air India                                0.260713         -0.026412
# Airline_GoAir                                   -0.092784          0.069148
# Airline_IndiGo                                  -0.341076          0.122809
# Airline_Jet Airways                              0.299088         -0.096568
# Airline_Jet Airways Business                    -0.011512         -0.002191
# Airline_Multiple carriers                        0.001100         -0.118164
# Airline_Multiple carriers Premium economy       -0.001406         -0.006709
# Airline_SpiceJet                                -0.262374          0.042655
# Airline_Trujet                                  -0.008200         -0.007652
# Airline_Vistara                                 -0.014727          0.043815
# Airline_Vistara Premium economy                 -0.016226          0.005141
# Source_Chennai                                  -0.186251         -0.098949
# Source_Delhi                                     0.280555         -0.163515
# Source_Kolkata                                   0.140774          0.018156
# Source_Mumbai                                   -0.232258         -0.017203
# Destination_Cochin                               0.280555         -0.163515
# Destination_Delhi                               -0.345514          0.224232
# Destination_Hyderabad                           -0.232258         -0.017203
# Destination_Kolkata                             -0.186251         -0.098949
# Destination_New Delhi                            0.015801          0.078637
# Duration_hours                                   1.000000         -0.133999
# Duration_minutes                                -0.133999          1.000000
# Journey_day                                     -0.046812         -0.007709
# Journey_month                                    0.056828         -0.021506
# Dep_Hours                                       -0.000648         -0.018843
# Dep_Minutes                                     -0.022147          0.089269
#
#                                            Journey_day  Journey_month  \
# Arrival_Time                                 -0.001934      -0.004014
# Total_Stops                                  -0.035371       0.065438
# Price                                        -0.147984       0.068811
# Airline_Air India                            -0.037436       0.002112
# Airline_GoAir                                 0.003205      -0.017674
# Airline_IndiGo                                0.016175      -0.036564
# Airline_Jet Airways                          -0.035165       0.055666
# Airline_Jet Airways Business                 -0.026241      -0.026936
# Airline_Multiple carriers                     0.051439      -0.002746
# Airline_Multiple carriers Premium economy     0.033582      -0.029848
# Airline_SpiceJet                              0.032433      -0.031875
# Airline_Trujet                               -0.010710       0.001519
# Airline_Vistara                              -0.015422       0.003280
# Airline_Vistara Premium economy              -0.017910      -0.012447
# Source_Chennai                                0.013520      -0.015108
# Source_Delhi                                  0.107855       0.005321
# Source_Kolkata                               -0.065527       0.065662
# Source_Mumbai                                -0.011954      -0.015820
# Destination_Cochin                            0.107855       0.005321
# Destination_Delhi                             0.013871       0.008979
# Destination_Hyderabad                        -0.011954      -0.015820
# Destination_Kolkata                           0.013520      -0.015108
# Destination_New Delhi                        -0.099225      -0.099300
# Duration_hours                               -0.046812       0.056828
# Duration_minutes                             -0.007709      -0.021506
# Journey_day                                   1.000000      -0.265200
# Journey_month                                -0.265200       1.000000
# Dep_Hours                                    -0.007617       0.028462
# Dep_Minutes                                  -0.013512       0.001922
#
#                                            Dep_Hours  Dep_Minutes
# Arrival_Time                               -0.000891     0.045949
# Total_Stops                                -0.067523    -0.002695
# Price                                       0.004967    -0.053522
# Airline_Air India                          -0.020731    -0.043883
# Airline_GoAir                              -0.016309     0.077403
# Airline_IndiGo                             -0.022254    -0.014346
# Airline_Jet Airways                         0.120596     0.022596
# Airline_Jet Airways Business               -0.007579     0.009245
# Airline_Multiple carriers                  -0.151549    -0.110297
# Airline_Multiple carriers Premium economy  -0.029004    -0.004653
# Airline_SpiceJet                           -0.010460     0.093068
# Airline_Trujet                              0.000890    -0.010084
# Airline_Vistara                             0.024881    -0.078720
# Airline_Vistara Premium economy            -0.003387    -0.011466
# Source_Chennai                             -0.014639     0.067710
# Source_Delhi                               -0.125286    -0.087885
# Source_Kolkata                              0.160484    -0.023347
# Source_Mumbai                              -0.016968     0.038091
# Destination_Cochin                         -0.125286    -0.087885
# Destination_Delhi                           0.010428     0.003314
# Destination_Hyderabad                      -0.016968     0.038091
# Destination_Kolkata                        -0.014639     0.067710
# Destination_New Delhi                      -0.022008     0.107839
# Duration_hours                             -0.000648    -0.022147
# Duration_minutes                           -0.018843     0.089269
# Journey_day                                -0.007617    -0.013512
# Journey_month                               0.028462     0.001922
# Dep_Hours                                   1.000000    -0.015068
# Dep_Minutes                                -0.015068     1.000000
#
# [29 rows x 29 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 10))  # Ajustez la taille 
heatmap = sns.heatmap(data.corr(), cmap="coolwarm", annot=False)  # annot=False pour supprimer les chiffres
plt.show()# annot=True is used for labelling the corr values

# %% [raw]
# # Heta map analysis
# # LInearity
# * We include columns which has high correlation with target.
# * We drop columns which has less correlation with target
# # Little or no multicollinearity
# * We include columns which has less correlation among each other
# * We drop one of the column if two input variable have high correlation.

# %%
# Calculate the correlation matrix
correlation_matrix = data.corr()

# Find the most correlated pairs of variables
most_correlated = correlation_matrix.stack().sort_values(ascending=False)

# Filter for pairs with correlation > 0.5 and < 1
most_correlated_filtered = most_correlated[(most_correlated > 0.4) & (most_correlated < 1)]

# Print the filtered pairs
print(most_correlated_filtered)
# Out:
# Duration_hours             Total_Stops                  0.730156
# Total_Stops                Duration_hours               0.730156
#                            Price                        0.662478
# Price                      Total_Stops                  0.662478
# Duration_hours             Price                        0.567567
# Price                      Duration_hours               0.567567
# Destination_Cochin         Total_Stops                  0.474480
# Source_Delhi               Total_Stops                  0.474480
# Total_Stops                Destination_Cochin           0.474480
#                            Source_Delhi                 0.474480
# Price                      Airline_Jet Airways          0.442693
# Airline_Jet Airways        Price                        0.442693
# Airline_Multiple carriers  Destination_Cochin           0.426279
# Source_Delhi               Airline_Multiple carriers    0.426279
# Destination_Cochin         Airline_Multiple carriers    0.426279
# Airline_Multiple carriers  Source_Delhi                 0.426279
# dtype: float64

# %% [markdown]
# ### Split data into x and y

# %%
x=data.drop("Price",axis=1)
y=data['Price']

# %%
# Important feature using ExtraTreesRegressor

from sklearn.ensemble import ExtraTreesRegressor
selection = ExtraTreesRegressor()
selection.fit(x, y)
# Out:
# ExtraTreesRegressor()

# %%
print(selection.feature_importances_)
# Out:
# [3.28221994e-02 2.70442834e-01 1.71882368e-02 2.20216825e-03
#  1.58559836e-02 1.62587028e-01 1.17038142e-04 2.44849814e-02
#  1.31714913e-03 3.38702011e-03 1.01434569e-04 7.19798984e-03
#  1.80561106e-04 7.32007739e-04 1.31124946e-02 7.96040356e-03
#  7.32638745e-03 1.50282978e-02 2.08243885e-02 5.99199631e-03
#  8.45081210e-04 1.54967653e-02 1.41741880e-01 2.41175744e-02
#  9.62161195e-02 5.37963021e-02 2.99823108e-02 2.89433668e-02]

# %%
#plot graph of feature importances for better visualization

plt.figure(figsize = (12,8))
feat_importances = pd.Series(selection.feature_importances_, index=x.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()

# %% [markdown]
# ### Split data for training and testing

# %% [markdown]
# # Sklearn
# It is one of the scientific library which includes all the packages related to Machine learning, data cleaning and feature engineering

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=4)

# %%
X_train.shape
# Out:
# (7323, 28)

# %%
X_test.shape
# Out:
# (3139, 28)

# %%
y_train.shape
# Out:
# (7323,)

# %%
y_test.shape
# Out:
# (3139,)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10462 entries, 0 to 10682
# Data columns (total 29 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Arrival_Time                               10462 non-null  int64
#  1   Total_Stops                                10462 non-null  int64
#  2   Price                                      10462 non-null  int64
#  3   Airline_Air India                          10462 non-null  uint8
#  4   Airline_GoAir                              10462 non-null  uint8
#  5   Airline_IndiGo                             10462 non-null  uint8
#  6   Airline_Jet Airways                        10462 non-null  uint8
#  7   Airline_Jet Airways Business               10462 non-null  uint8
#  8   Airline_Multiple carriers                  10462 non-null  uint8
#  9   Airline_Multiple carriers Premium economy  10462 non-null  uint8
#  10  Airline_SpiceJet                           10462 non-null  uint8
#  11  Airline_Trujet                             10462 non-null  uint8
#  12  Airline_Vistara                            10462 non-null  uint8
#  13  Airline_Vistara Premium economy            10462 non-null  uint8
#  14  Source_Chennai                             10462 non-null  uint8
#  15  Source_Delhi                               10462 non-null  uint8
#  16  Source_Kolkata                             10462 non-null  uint8
#  17  Source_Mumbai                              10462 non-null  uint8
#  18  Destination_Cochin                         10462 non-null  uint8
#  19  Destination_Delhi                          10462 non-null  uint8
#  20  Destination_Hyderabad                      10462 non-null  uint8
#  21  Destination_Kolkata                        10462 non-null  uint8
#  22  Destination_New Delhi                      10462 non-null  uint8
#  23  Duration_hours                             10462 non-null  float64
#  24  Duration_minutes                           10462 non-null  float64
#  25  Journey_day                                10462 non-null  int64
#  26  Journey_month                              10462 non-null  int64
#  27  Dep_Hours                                  10462 non-null  int32
#  28  Dep_Minutes                                10462 non-null  int32
# dtypes: float64(2), int32(2), int64(5), uint8(20)
# memory usage: 939.9 KB

# %% [markdown]
# # Building model RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
reg_rf = RandomForestRegressor()
reg_rf.fit(X_train, y_train)
y_pred = reg_rf.predict(X_test)
reg_rf.score(X_train, y_train)
r2 = reg_rf.score(X_test, y_test)

# %% [markdown]
# # Evaluate the model

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
# MSE(Mean Squared error)
MSE=mean_squared_error(y_test,y_pred)
# MAE(Mean absolute error)
MAE=mean_absolute_error(y_test,y_pred)
# RMSE(Root mean squared error)
rmse=np.sqrt(MSE)
# r2_score
r2 = r2_score(y_test,y_pred)

print("Mean Absolute Error (MAE):", MAE)
print("Mean Squared Error (MSE):", MSE)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R2) Score:", r2)
# Out:
# Mean Absolute Error (MAE): 1160.0637377779294
# Mean Squared Error (MSE): 3157735.573817897
# Root Mean Squared Error (RMSE): 1777.0018496945627
# R-squared (R2) Score: 0.8045454275496811

# %% [markdown]
# # Visualize the result

# %% [markdown]
# ### Scatter plot
# A scatter plot is a straightforward way to visualize how well the predicted values align with the actual target values. We can create a scatter plot with the actual target values on the x-axis and the predicted values on the y-axis. Points that fall along a diagonal line represent perfect predictions.

# %%
# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Scatter Plot of Actual vs. Predicted Values")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Residual plot
# A residual plot shows the residuals, which are the differences between the actual and predicted values. This plot helps identify patterns or trends in the residuals, which can provide insights into the model's performance.

# %%
# Calculate the residuals
residuals = y_test - y_pred
# Create a residual plot
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, residuals, alpha=0.5)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Trying different hyperparameter combinations : Grid Search:

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_leaf': [1, 5, 10]
}

# Create a RandomForestRegressor
rf = RandomForestRegressor(random_state=42)

# Create the GridSearchCV object
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, 
                           cv=5, scoring='neg_mean_squared_error', verbose=1, n_jobs=-1)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_
best_mse = -grid_search.best_score_  # GridSearchCV uses negative MSE for scoring

print("Best Hyperparameters:", best_params)
print("Best Mean Squared Error:", best_mse)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best Hyperparameters: {'max_depth': 20, 'min_samples_leaf': 5, 'n_estimators': 300}
# Best Mean Squared Error: 3166337.7503266963

# %%
# Instantiate the RandomForestRegressor with the best hyperparameters
best_rf = RandomForestRegressor(n_estimators=300, max_depth=20, min_samples_leaf=5, random_state=42)

# Fit the model to your training data
best_rf.fit(X_train, y_train)
y_pred = best_rf.predict(X_test)
best_rf.score(X_train, y_train)
best_rf.score(X_test, y_test)
# MSE(Mean Squared error)
MSE=mean_squared_error(y_test,y_pred)
# MAE(Mean absolute error)
MAE=mean_absolute_error(y_test,y_pred)
# RMSE(Root mean squared error)
rmse=np.sqrt(MSE)
# r2_score
r2 = r2_score(y_test,y_pred)

print("Mean Absolute Error (MAE):", MAE)
print("Mean Squared Error (MSE):", MSE)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared (R2) Score:", r2)
# Out:
# Mean Absolute Error (MAE): 1145.438080225356
# Mean Squared Error (MSE): 2877899.5017691883
# Root Mean Squared Error (RMSE): 1696.4372967396077
# R-squared (R2) Score: 0.821866459833688

# %%
from sklearn.model_selection import cross_val_score

# Create a RandomForestRegressor with the best hyperparameters
best_rf = RandomForestRegressor(n_estimators=best_params['n_estimators'],
                                max_depth=best_params['max_depth'],
                                min_samples_leaf=best_params['min_samples_leaf'],
                                random_state=42)

# Perform k-fold cross-validation
cv_scores = cross_val_score(best_rf, x, y, cv=5, scoring='neg_mean_squared_error')

# Calculate the mean squared error and its standard deviation
mse_mean = -cv_scores.mean()
mse_std = cv_scores.std()

print("Cross-Validation Mean Squared Error:", mse_mean)
print("Cross-Validation MSE Standard Deviation:", mse_std)
# Out:
# Cross-Validation Mean Squared Error: 2939898.585568541
# Cross-Validation MSE Standard Deviation: 174656.55252879506
