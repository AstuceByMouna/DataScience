# %% [markdown]
# # Domain Analysis of Skin Disorder Dataset
#
# ## Features in the Dataset
#
# ### Clinical Features:
# 1. **Erythema:** Redness of the skin, often indicating inflammation or irritation.
# 2. **Scaling:** Presence of scales or flaking of the skin, associated with conditions like psoriasis or dermatitis.
# 3. **Definite Borders:** Indicates well-defined boundaries of skin lesions.
# 4. **Itching:** Common symptom of skin disorders.
# 5. **Koebner Phenomenon:** Development of skin lesions at sites of trauma or injury.
# 6. **Polygonal Papules:** Small, raised skin lesions with polygonal shape.
# 7. **Follicular Papules:** Papules involving hair follicles.
# 8. **Oral Mucosal Involvement:** Involvement of the oral mucosa.
# 9. **Knee and Elbow Involvement:** Distribution of skin lesions on joints.
# 10. **Scalp Involvement:** Presence of skin issues on the scalp.
#
# ### Historical Features:
# 11. **Family History:** Family history of skin disorders.
# 12. **Melanin Incontinence:** Leakage of melanin pigment from melanocytes.
# 13. **Eosinophils in the Infiltrate:** Presence of eosinophils in the inflammatory infiltrate.
# 14. **PNL Infiltrate:** Presence of polymorphonuclear leukocytes in the infiltrate.
# 15. **Fibrosis of the Papillary Dermis:** Excess fibrous tissue formation in the dermal layer.
# 16. **Exocytosis:** Migration of lymphocytes into the epidermis.
# 17. **Acanthosis:** Thickening of the epidermis.
# 18. **Hyperkeratosis:** Thickening of the stratum corneum.
# 19. **Parakeratosis:** Retention of cell nuclei in the stratum corneum.
# 20. **Clubbing of the Rete Ridges:** Changes in rete ridges.
# 21. **Elongation of the Rete Ridges:** Elongation of rete ridges.
# 22. **Thinning of the Suprapapillary Epidermis:** Thinning of this layer.
# 23. **Spongiform Pustule:** A type of skin lesion.
# 24. **Munro Microabscess:** Collections of neutrophils in the stratum corneum.
# 25. **Focal Hypergranulosis:** Increase in granular layer thickness.
# 26. **Disappearance of the Granular Layer:** Changes in the granular layer.
# 27. **Vacuolization and Damage of Basal Layer:** Formation of vacuoles in cells.
# 28. **Spongiosis:** Accumulation of fluid between epidermal cells.
# 29. **Saw-Tooth Appearance of Rete's:** Structural changes in rete ridges.
# 30. **Follicular Horn Plug:** Keratinous material in hair follicles.
#
# ### Demographic and Target Variables:
# 31. **Perifollicular Parakeratosis:** Parakeratosis around hair follicles.
# 32. **Inflammatory Mononuclear Infiltrate:** Presence of mononuclear immune cells.
# 33. **Band-Like Infiltrate:** Inflammatory infiltrate forming a band-like pattern.
# 34. **Age:** Age of the patients.
# 35. **Class (Target Variable):** Specific skin disorder or disease being diagnosed.
#
# ---
#
# This dataset contain a diverse set of clinical, histopathological, and demographic features related to skin disorders. It can be used for diagnostic purposes and predictive modeling to classify different skin conditions based on the provided features.

# %% [markdown]
# ### 1. Loading Dataset:

# %%
## import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
from scipy.stats import chi2_contingency

# %%
# !pip install matplotlib

# %% [markdown]
# ### 2. Exploring Data:

# %%
data
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# ...

# %%
data.columns
# Out:
# Index(['erythema', 'scaling', 'definite_borders', 'itching',
#        'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
#        'oral_mucosal_involvement', 'knee_and_elbow_involvement',
#        'scalp_involvement', 'family_history', 'melanin_incontinence',
#        'eosinophils_in_the_infiltrate', 'PNL_infiltrate',
#        'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis',
#        'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges',
#        'elongation_of_the_rete_ridges',
#        'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule',
#        'munro_microabcess', 'focal_hypergranulosis',
#        'disappearance_of_the_granular_layer',
#        'vacuolisation_and_damage_of_basal_layer', 'spongiosis',
#        'saw-tooth_appearance_of_retes', 'follicular_horn_plug',
#        'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate',
#        'band-like_infiltrate', 'Age', 'class'],
#       dtype='object')

# %%
data.shape
# Out:
# (366, 35)

# %%
data.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  \
# 0                           1                  0  ...
# ...

# %%
data.describe()
# Out:
#          erythema     scaling  definite_borders     itching  \
# count  366.000000  366.000000        366.000000  366.000000
# mean     2.068306    1.795082          1.549180    1.366120
# std      0.664753    0.701527          0.907525    1.138299
# min      0.000000    0.000000          0.000000    0.000000
# 25%      2.000000    1.000000          1.000000    0.000000
# 50%      2.000000    2.000000          2.000000    1.000000
# 75%      2.000000    2.000000          2.000000    2.000000
# max      3.000000    3.000000          3.000000    3.000000
#
#        koebner_phenomenon  polygonal_papules  follicular_papules  \
# count          366.000000         366.000000          366.000000
# mean             0.633880           0.448087            0.166667
# std              0.908016           0.957327            0.570588
# min              0.000000           0.000000            0.000000
# 25%              0.000000           0.000000            0.000000
# ...

# %%
data.dtypes
# Out:
# erythema                                     int64
# scaling                                      int64
# definite_borders                             int64
# itching                                      int64
# koebner_phenomenon                           int64
# polygonal_papules                            int64
# follicular_papules                           int64
# oral_mucosal_involvement                     int64
# knee_and_elbow_involvement                   int64
# scalp_involvement                            int64
# family_history                               int64
# melanin_incontinence                         int64
# eosinophils_in_the_infiltrate                int64
# PNL_infiltrate                               int64
# fibrosis_of_the_papillary_dermis             int64
# exocytosis                                   int64
# acanthosis                                   int64
# hyperkeratosis                               int64
# ...

# %%
df = pd.DataFrame(data)

# %%
data.isnull().sum()
# Out:
# erythema                                    0
# scaling                                     0
# definite_borders                            0
# itching                                     0
# koebner_phenomenon                          0
# polygonal_papules                           0
# follicular_papules                          0
# oral_mucosal_involvement                    0
# knee_and_elbow_involvement                  0
# scalp_involvement                           0
# family_history                              0
# melanin_incontinence                        0
# eosinophils_in_the_infiltrate               0
# PNL_infiltrate                              0
# fibrosis_of_the_papillary_dermis            0
# exocytosis                                  0
# acanthosis                                  0
# hyperkeratosis                              0
# parakeratosis                               0
# clubbing_of_the_rete_ridges                 0
# ...

# %%
# Count the number of duplicated rows
num_duplicates = df.duplicated().sum()

print(f"Number of duplicated rows: {num_duplicates}")
# Out:
# Number of duplicated rows: 0

# %%
df = pd.DataFrame(data)
# Get unique values in each column
for col in df.columns:
    unique_values = df[col].unique()
    print(f"Valeurs uniques dans la colonne '{col}': {unique_values}")
# Out:
# Valeurs uniques dans la colonne 'erythema': [2 3 1 0]
# Valeurs uniques dans la colonne 'scaling': [2 3 1 0]
# Valeurs uniques dans la colonne 'definite_borders': [0 3 2 1]
# Valeurs uniques dans la colonne 'itching': [3 2 0 1]
# Valeurs uniques dans la colonne 'koebner_phenomenon': [0 1 2 3]
# Valeurs uniques dans la colonne 'polygonal_papules': [0 3 2 1]
# Valeurs uniques dans la colonne 'follicular_papules': [0 3 1 2]
# Valeurs uniques dans la colonne 'oral_mucosal_involvement': [0 3 2 1]
# Valeurs uniques dans la colonne 'knee_and_elbow_involvement': [1 0 3 2]
# Valeurs uniques dans la colonne 'scalp_involvement': [0 1 2 3]
# Valeurs uniques dans la colonne 'family_history': [0 1]
# Valeurs uniques dans la colonne 'melanin_incontinence': [0 1 2 3]
# Valeurs uniques dans la colonne 'eosinophils_in_the_infiltrate': [0 2 1]
# Valeurs uniques dans la colonne 'PNL_infiltrate': [0 1 3 2]
# Valeurs uniques dans la colonne 'fibrosis_of_the_papillary_dermis': [0 3 1 2]
# ...

# %%
data[data["Age"] == "?"]
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 33          2        2                 1        0                   0
# 34          2        1                 0        0                   2
# 35          2        2                 1        2                   0
# 36          2        1                 2        3                   2
# 262         2        1                 0        2                   0
# 263         1        1                 1        3                   0
# 264         1        1                 0        2                   0
# 265         1        1                 0        3                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 33                   0                   0                         0
# 34                   0                   0                         0
# 35                   0                   0                         0
# ...

# %%
# Replace '?' with NaN in the "Age" column
df['Age'] = df['Age'].replace('?', float('nan'))

# Calculate the median of the "Age" column
median_age = df['Age'].median()

# Fill missing values with the median
df['Age'].fillna(median_age, inplace=True)

# %%
df.dtypes
# Out:
# erythema                                     int64
# scaling                                      int64
# definite_borders                             int64
# itching                                      int64
# koebner_phenomenon                           int64
# polygonal_papules                            int64
# follicular_papules                           int64
# oral_mucosal_involvement                     int64
# knee_and_elbow_involvement                   int64
# scalp_involvement                            int64
# family_history                               int64
# melanin_incontinence                         int64
# eosinophils_in_the_infiltrate                int64
# PNL_infiltrate                               int64
# fibrosis_of_the_papillary_dermis             int64
# exocytosis                                   int64
# acanthosis                                   int64
# hyperkeratosis                               int64
# ...

# %%
df['Age'] = df['Age'].astype(int).astype(pd.Int64Dtype())

# %%
df.dtypes
# Out:
# erythema                                    int64
# scaling                                     int64
# definite_borders                            int64
# itching                                     int64
# koebner_phenomenon                          int64
# polygonal_papules                           int64
# follicular_papules                          int64
# oral_mucosal_involvement                    int64
# knee_and_elbow_involvement                  int64
# scalp_involvement                           int64
# family_history                              int64
# melanin_incontinence                        int64
# eosinophils_in_the_infiltrate               int64
# PNL_infiltrate                              int64
# fibrosis_of_the_papillary_dermis            int64
# exocytosis                                  int64
# acanthosis                                  int64
# hyperkeratosis                              int64
# parakeratosis                               int64
# ...

# %% [markdown]
# ### 3. Univariate analysis

# %%
for column in numerical_columns:
    try:
        plt.figure(figsize=(10, 4))
        
        # Histogram
        plt.subplot(1, 2, 1)
        sns.histplot(df[column], kde=True)
        plt.title(f'Histogram of {column}')
        
        # Boxplot
        plt.subplot(1, 2, 2)
        sns.boxplot(y=df[column])
        plt.title(f'Boxplot of {column}')
        
        plt.tight_layout()
        
        # Save the plot as an image file in the 'plots' folder
        plt.savefig(f'plots/{column}_univariate.png')
        plt.close()
    except Exception as e:
        print(f"Error plotting {column}: {str(e)}")
# Out:
# Error plotting Age: loop of ufunc does not support argument 0 of type float which has no callable sqrt method

# %%
pip install pillow

# %%
data["class"].value_counts()

# %% [markdown]
# #### class imbalance in the dataset

# %%
display(Image(filename=f'plots/class_univariate.png'))

# %%
from IPython.display import Image, display
display(Image(filename=f'plots/erythema_univariate.png'))

# %%
display(Image(filename=f'plots/scaling_univariate.png'))

# %%
display(Image(filename=f'plots/definite_borders_univariate.png'))

# %%
display(Image(filename=f'plots/itching_univariate.png'))

# %%
display(Image(filename=f'plots/koebner_phenomenon_univariate.png'))

# %%
display(Image(filename=f'plots/polygonal_papules_univariate.png'))

# %%
display(Image(filename=f'plots/follicular_papules_univariate.png'))

# %%
display(Image(filename=f'plots/oral_mucosal_involvement_univariate.png'))

# %%
display(Image(filename=f'plots/knee_and_elbow_involvement_univariate.png'))

# %%
display(Image(filename=f'plots/scalp_involvement_univariate.png'))

# %%
display(Image(filename=f'plots/family_history_univariate.png'))

# %%
display(Image(filename=f'plots/melanin_incontinence_univariate.png'))

# %%
display(Image(filename=f'plots/eosinophils_in_the_infiltrate_univariate.png'))

# %%
display(Image(filename=f'plots/PNL_infiltrate_univariate.png'))

# %%
display(Image(filename=f'plots/fibrosis_of_the_papillary_dermis_univariate.png'))

# %%
display(Image(filename=f'plots/exocytosis_univariate.png'))

# %%
display(Image(filename=f'plots/acanthosis_univariate.png'))

# %%
display(Image(filename=f'plots/hyperkeratosis_univariate.png'))

# %%
display(Image(filename=f'plots/parakeratosis_univariate.png'))

# %%
display(Image(filename=f'plots/clubbing_of_the_rete_ridges_univariate.png'))

# %%
display(Image(filename=f'plots/elongation_of_the_rete_ridges_univariate.png'))

# %%
display(Image(filename=f'plots/thinning_of_the_suprapapillary_epidermis_univariate.png'))

# %%
display(Image(filename=f'plots/spongiform_pustule_univariate.png'))

# %%
display(Image(filename=f'plots/munro_microabcess_univariate.png'))

# %%
display(Image(filename=f'plots/focal_hypergranulosis_univariate.png'))

# %%
display(Image(filename=f'plots/disappearance_of_the_granular_layer_univariate.png'))

# %%
display(Image(filename=f'plots/vacuolisation_and_damage_of_basal_layer_univariate.png'))

# %%
display(Image(filename=f'plots/saw-tooth_appearance_of_retes_univariate.png'))

# %%
display(Image(filename=f'plots/follicular_horn_plug_univariate.png'))

# %%
display(Image(filename=f'plots/perifollicular_parakeratosis_univariate.png'))

# %%
display(Image(filename=f'plots/inflammatory_monoluclear_inflitrate_univariate.png'))

# %%
display(Image(filename=f'plots/band-like_infiltrate_univariate.png'))

# %%
display(Image(filename=f'plots/Age_univariate.png'))

# %% [markdown]
# ### 4. Bivariate analysis

# %% [markdown]
# #### a. Cross-Tabulation (Contingency Tables):

# %%
# Create a cross-tabulation (contingency table) between "itching" and "class"
cross_tab = pd.crosstab(df['itching'], df['class'])
cross_tab

# %%
import seaborn as sns


# Continuous vs. Continuous Variables (Scatter plot and correlation matrix)
sns.pairplot(df, kind="scatter")
plt.show()

# Correlation matrix
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# Categorical vs. Categorical Variables (Contingency table and Chi-squared test)
contingency_table = pd.crosstab(df['Category1'], df['Category2'])
chi2, p, _, _ = stats.chi2_contingency(contingency_table)
print("Chi-squared statistic:", chi2)
print("P-value:", p)

# Categorical vs. Continuous Variables (Box plots and t-test)
sns.boxplot(x="Category1", y="NumericVariable", data=df)
plt.xlabel("Category1")
plt.ylabel("NumericVariable")
plt.title("Box Plot by Category1")
plt.show()

# Perform t-test
from scipy import stats
group1 = df[df['Category1'] == 'A']['NumericVariable']
group2 = df[df['Category1'] == 'B']['NumericVariable']
t_statistic, p_value = stats.ttest_ind(group1, group2)
print("T-statistic:", t_statistic)
print("P-value:", p_value)

# Time Series Analysis (Line plot for a time series variable)
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df['TimeSeriesVariable'].plot(figsize=(12, 6))
plt.xlabel("Date")
plt.ylabel("TimeSeriesVariable")
plt.title("Time Series Plot")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


target_variable = 'class'

categorical_vars = ['erythema', 'scaling', 'definite_borders', 'itching', 'koebner_phenomenon', 'polygonal_papules', 
                    'follicular_papules', 'oral_mucosal_involvement', 'knee_and_elbow_involvement', 'scalp_involvement', 
                    'family_history', 'melanin_incontinence', 'eosinophils_in_the_infiltrate', 'PNL_infiltrate', 
                    'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis', 'hyperkeratosis', 'parakeratosis', 
                    'clubbing_of_the_rete_ridges', 'elongation_of_the_rete_ridges', 'thinning_of_the_suprapapillary_epidermis', 
                    'spongiform_pustule', 'munro_microabscess', 'focal_hypergranulosis', 'disappearance_of_the_granular_layer', 
                    'vacuolization_and_damage_of_basal_layer', 'spongiosis', 'saw-tooth_appearance_of_retes', 
                    'follicular_horn_plug', 'perifollicular_parakeratosis', 'inflammatory_mononuclear_infiltrate', 
                    'band-like_infiltrate']

# Numerical variables
numerical_vars = ['Age']

# Bivariate analysis for categorical variables
for var in categorical_vars:
    plt.figure(figsize=(8, 4))
    sns.countplot(data=data, x=var, hue=target_variable)
    plt.title(f'Bivariate Analysis for {var}')
    plt.xticks(rotation=90)
    plt.show()

# Bivariate analysis for numerical variables
for var in numerical_vars:
    plt.figure(figsize=(8, 4))
    sns.boxplot(data=data, x=target_variable, y=var)
    plt.title(f'Bivariate Analysis for {var}')
    plt.show()

# %%
insights:
- Erythema: class 1 and 3 of Skin Disorder are more present in erythema class 2 and 3 and class 5 of Skin Disorder is more present in erythema class 1 and 2 
- Scaling : class 1 and 2 of Skin Disorder are more present in scaling class 2, class 5 of Skin Disorder is more present in scaling class 1
- borders : class 1 and 3 of Skin Disorder are more present in borders class 2
- itching : class 1 and 4 of Skin Disorder are more present in itching class 0
- phenomenon: class 1, 2 and 5 of Skin Disorder is more present in phenomenon class 0
- polygonal_papules : class 3 of Skin Disorder is more present in polygonal_papules class 2 and 3
- follicular_papules : class 6 of Skin Disorder is more present in follicular_papules class 2 
- oral_mucosal_involvement : class 3 of Skin Disorder is more present in oral_mucosal_involvement class 2 
- knee_and_elbow_involvement: class 2 of Skin Disorder is more present in knee_and_elbow_involvement class 2
- scalp_involvement: class 3 of Skin Disorder is more present in scalp_involvement class 2
- family history :  there is no discrimination effect between Skin Disorder classes
- melanin_incontinence : class 3 of Skin Disorder is more present in melanin_incontinence class 2
- eosinophilis_in_the_infiltrate : there is no discrimination effect between Skin Disorder classes
- PNL_infiltrate: class 3 of Skin Disorder is exclusively present in PNL_infiltrate class 0
- fibrosis_of_the_papillary_dermis: class 3 of Skin Disorder is exclusively present in fibrosis_of_the_papillary_dermis class 0
- exocytosis : class 3 of Skin Disorder is more present in exocytosis class 0
- acanothosis : class 1 of Skin Disorder is more present in acanothosis  class 2
- hyperkeratosis: there is no discrimination effect between Skin Disorder classes
- parakeratosis : class 1 of Skin Disorder is more present in parakeratosis  class 2
- clubbing_of_the_rete_ridges : clubbing_of_the_rete_ridges class 0 is sygnificant for all Skin Disorder class except class 1
- elongation_of_the_rete_ridges : there is no discrimination effect between Skin Disorder classes
- thinning_of_the_suprapapillary_epidermis : there is no discrimination effect between Skin Disorder classes
- spongiform_pustules : there is no discrimination effect between Skin Disorder classes
-

# %%
import seaborn as sns

# Calculate the correlation matrix
corr_matrix = df.corr()

corr_matrix

# %%
# Plot the correlation heatmap
plt.figure(figsize=(40, 40))
sns.heatmap(corr_matrix, annot=True, cmap='Blues', annot_kws={"size":15})
plt.title('Correlation Heatmap')
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Assuming you have a DataFrame 'df' containing your data
# Replace 'df' with your actual DataFrame

# Select numerical columns from your DataFrame
numerical_columns = df.select_dtypes(include=['int64', 'float64'])

# Select the 'class' column (categorical)
categorical_column = df['class']

# Standardize or normalize the numerical data
scaler = StandardScaler()
scaled_data = scaler.fit_transform(numerical_columns)

# Encode the 'class' column to numerical values
label_encoder = LabelEncoder()
encoded_class = label_encoder.fit_transform(categorical_column)

# Initialize t-SNE with desired hyperparameters
tsne = TSNE(n_components=2, perplexity=30, learning_rate=200)

# Fit and transform the data using t-SNE
X_tsne = tsne.fit_transform(scaled_data)

# Create a scatterplot with colors based on the encoded 'class' column
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=encoded_class, cmap='viridis', s=30)
plt.title("t-SNE Visualization with 'class' Colors")
plt.xlabel("t-SNE Dimension 1")
plt.ylabel("t-SNE Dimension 2")

# Add a colorbar to represent the 'class' values
cbar = plt.colorbar(scatter)
cbar.set_label('Encoded Class')

plt.show()

# %%
import sweetviz as sv#importing sweetviz library 
my_report1 = sv.analyze(data)#syntax to use sweetviz
my_report1.show_html()#Default arguments will generate to "SWEETVIZ_REPORT.html"

# %%
# Calculer les corrélations entre les variables
correlation_matrix = df.corr()

# Filtrer les paires de variables dont la corrélation est supérieure à 0.6 ou inférieure à -0.6
threshold = 0.6
high_correlation_pairs = []
low_correlation_pairs = []

for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        corr = correlation_matrix.iloc[i, j]
        if corr > threshold:
            high_correlation_pairs.append((correlation_matrix.columns[i], correlation_matrix.columns[j], corr))
        elif corr < -threshold:
            low_correlation_pairs.append((correlation_matrix.columns[i], correlation_matrix.columns[j], corr))

# Afficher les paires de variables dont la corrélation dépasse le seuil
print("Paires de variables avec une corrélation > 0.6 :")
for pair in high_correlation_pairs:
    print(f"{pair[0]} - {pair[1]} : {pair[2]}")

print("\nPaires de variables avec une corrélation < -0.6 :")
for pair in low_correlation_pairs:
    print(f"{pair[0]} - {pair[1]} : {pair[2]}")

# %%
insight: class is highly correlated with clubbing_of_the_rete_ridges and thinning_of_the_suprapapillary_epidermis

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency, pointbiserialr

# Créez un DataFrame exemple avec des colonnes numériques et catégorielles
data = {
    'Numerical_Var1': [1, 2, 3, 4, 5],
    'Categorical_Var1': ['A', 'B', 'A', 'B', 'A'],
    'Numerical_Var2': [5, 4, 3, 2, 1],
    'Categorical_Var2': ['B', 'A', 'B', 'A', 'B'],
}

df = pd.DataFrame(data)

# Liste pour stocker les corrélations significatives
corr_results = []

# Boucle à travers les colonnes pour trouver les corrélations
for col1 in df.columns:
    for col2 in df.columns:
        if col1 != col2:
            # Déterminer les types de données des deux colonnes
            is_num1 = np.issubdtype(df[col1].dtype, np.number)
            is_num2 = np.issubdtype(df[col2].dtype, np.number)

            # Calculer la corrélation
            if is_num1 and is_num2:
                # Numérique-Numérique : Utilisez la corrélation de Pearson
                correlation, p_value = df[col1].corr(df[col2], method='pearson'), None
            elif not is_num1 and not is_num2:
                # Catégoriel-Catégoriel : Utilisez Cramer's V
                contingency_table = pd.crosstab(df[col1], df[col2])
                chi2, p_value, _, _ = chi2_contingency(contingency_table)
                n = df.shape[0]
                correlation = np.sqrt(chi2 / (n * (min(contingency_table.shape) - 1)))
            else:
                # Numérique-Catégoriel : Utilisez la corrélation de point-biserial
                if is_num1:
                    num_col, cat_col = col1, col2
                else:
                    num_col, cat_col = col2, col1
                # Convertissez les catégories en numériques (par exemple, 0 et 1)
                df[cat_col] = df[cat_col].astype('category').cat.codes
                correlation, p_value = pointbiserialr(df[cat_col], df[num_col])

            # Vérifiez la significativité (généralement p-value < 0.05)
            if p_value is not None and p_value < 0.05:
                corr_results.append((col1, col2, correlation, p_value))

# Affichez les corrélations significatives
for col1, col2, correlation, p_value in corr_results:
    print(f"{col1} - {col2}: Corrélation={correlation}, p-value={p_value}")
