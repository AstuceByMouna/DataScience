# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

data1=pd.read_csv("dataset/time_series_covid19_confirmed_global.csv")
data2=pd.read_csv("dataset/time_series_covid19_deaths_global.csv")
data3=pd.read_csv("dataset/time_series_covid19_recovered_global.csv")

# %% [markdown]
# like previous data lack of informations
#
# for flights we don't have cost of flight infi
# here lack of info about population ...
#
# testing rates /
# vaccination rates:
# population size:
# age distribution:
# healthcare capacity
# travel restrictions
# lockdowns
# social distancing measures/disponibility of musks, lotions ...
# Weather conditions
#
#
# Input :
#
# Time Information: This can include dates, timestamps, or time intervals. It's a crucial input for time series forecasting.
# Geographic Information: Depending on the level of granularity you're interested in, you may include data related to regions, countries, or specific locations.
#
# Output :
#
# COVID-19 Cases: The number of confirmed COVID-19 cases for a specific location and time period.
# COVID-19 Deaths: The number of COVID-19-related deaths for a specific location and time period.
# COVID-19 Recoveries: The number of individuals who have recovered from COVID-19 for a specific location and time period.

# %%
data1
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 261            NaN  West Bank and Gaza  31.952200  35.233200        0
# 262            NaN      Western Sahara  24.215500 -12.885800        0
# 263            NaN               Yemen  15.552727  48.516388        0
# 264            NaN              Zambia -13.133897  27.849332        0
# 265            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  9/12/20  9/13/20  \
# ...

# %%
data2
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 261            NaN  West Bank and Gaza  31.952200  35.233200        0
# 262            NaN      Western Sahara  24.215500 -12.885800        0
# 263            NaN               Yemen  15.552727  48.516388        0
# 264            NaN              Zambia -13.133897  27.849332        0
# 265            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  9/12/20  9/13/20  \
# ...

# %%
data3
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110  67.709953        0
# 1              NaN             Albania  41.153300  20.168300        0
# 2              NaN             Algeria  28.033900   1.659600        0
# 3              NaN             Andorra  42.506300   1.521800        0
# 4              NaN              Angola -11.202700  17.873900        0
# ..             ...                 ...        ...        ...      ...
# 248            NaN  West Bank and Gaza  31.952200  35.233200        0
# 249            NaN      Western Sahara  24.215500 -12.885800        0
# 250            NaN               Yemen  15.552727  48.516388        0
# 251            NaN              Zambia -13.133897  27.849332        0
# 252            NaN            Zimbabwe -19.015438  29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  9/12/20  9/13/20  \
# ...

# %%
if data1.columns.equals(data2.columns) and data2.columns.equals(data3.columns):
    print("All DataFrames have the same columns.")
else:
    print("DataFrames do not have the same columns.")
# Out:
# All DataFrames have the same columns.

# %%
data1.duplicated().sum()
# Out:
# 0

# %%
data2.duplicated().sum()
# Out:
# 0

# %%
data3.duplicated().sum()
# Out:
# 0

# %%
data1["Country/Region"].nunique()
# Out:
# 188

# %%
data2["Country/Region"].nunique()
# Out:
# 188

# %%
data3["Country/Region"].nunique()
# Out:
# 188

# %%
data1["Province/State"].isna().sum()
# Out:
# 185

# %%
data2["Province/State"].isna().sum()

# %%
data3["Province/State"].isna().sum()
# Out:
# 186
